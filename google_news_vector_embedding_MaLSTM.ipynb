# %%
# GPU info
# !nvidia-smi
# Out:
# Wed Feb 10 21:58:25 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import os

import tensorflow as tf
import keras.backend as K

from keras.preprocessing.sequence import pad_sequences
from keras.layers.embeddings import Embedding

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import pickle

# %%
import re
import string

import nltk

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import RegexpTokenizer

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("/content/drive/My Drive/Duplicate Question Detection/quora_questions.csv")
#data.fillna("none value", inplace=True) # replace nan value to none
# drop the rows with null value
data.dropna(axis=0, inplace=True)
N=len(data)
print('Number of question pairs: ', N)
data.head()
# Out:
# Number of question pairs:  404348
#    id  qid1  ...                                          question2 is_duplicate
# 0   0     1  ...  What is the step by step guide to invest in sh...            0
# 1   1     3  ...  What would happen if the Indian government sto...            0
# 2   2     5  ...  How can Internet speed be increased by hacking...            0
# 3   3     7  ...  Find the remainder when [math]23^{24}[/math] i...            0
# 4   4     9  ...            Which fish would survive in salt water?            0
#
# [5 rows x 6 columns]

# %%
# def cut_to_max(text, max_len):
#     words = text.split()[:max_len]
#     return ' '.join(words)

# # test the func
# # cut_to_max(' abc test wewe dfd ddd', 3)

# %%
# data['question1'] = data['question1'].apply(lambda x: cut_to_max(x, 65))
# data['question2'] = data['question2'].apply(lambda x: cut_to_max(x, 65))

# %%
# model selection
from sklearn.model_selection import train_test_split
data_train2 , data_test = train_test_split(data, train_size=0.8, random_state=0)
data_train , data_test2 = train_test_split(data_train2, train_size=0.38, random_state=0)
# validation_data, _ = train_test_split(data_train, train_size=0.1, random_state=0)
len(data_train)/len(data)
# Out:
# 0.30399804129116503

# %%
train_Q1 = np.array(data_train['question1'])
train_Q2 = np.array(data_train['question2'])
t_labels = np.array(data_train['is_duplicate'])
# make it one-hot encoding
train_labels = tf.keras.utils.to_categorical(t_labels, num_classes=2)

test_Q1 = np.array(data_test['question1'])
test_Q2 = np.array(data_test['question2'])
te_labels  = np.array(data_test['is_duplicate'])
# make it one-hot encoding
test_labels = tf.keras.utils.to_categorical(te_labels, num_classes=2)

# %%
#create arrays

Q1_train_tensor = np.empty_like(train_Q1)
Q2_train_tensor = np.empty_like(train_Q2)

Q1_test_tensor = np.empty_like(test_Q1)
Q2_test_tensor = np.empty_like(test_Q2)

Q1_train_tensor.shape, Q1_test_tensor.shape
# Out:
# ((122921,), (80870,))

# %%
# # tokenize
# tokenizer = RegexpTokenizer(r'\w+')
# stemmer = PorterStemmer()
# def process_question(question):
#     words = [word.lower() for word in tokenizer.tokenize(question)]
#     # remove_stopwords = [word for word in words if word not in stopwords.words('english')]
#     # stemmed_words = [stemmer.stem(word) for word in remove_stopwords]
#     return words

# %%
def text_to_word_list(text):
    ''' Pre process and convert texts to a list of words '''
    text = str(text)
    text = text.lower()

    # Clean the text
    #text = re.sub(r"[^A-Za-z0-9^,!.?\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"What's", "What is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"Can't", "Cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"I'm", "I am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " , ", text)
    text = re.sub(r"\.", " . ", text)
    text = re.sub(r"\?", " ? ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)

    text = text.split()

    return text

# %%
# # process train and test questions

Q1_train_words = {}
Q2_train_words = {}

Q1_test_words = {}
Q2_test_words = {}

for idx in range(len(train_Q1)):
    Q1_train_words[idx] = text_to_word_list(train_Q1[idx])
    Q2_train_words[idx] = text_to_word_list(train_Q2[idx])

for idx in range(len(test_Q1)): 
    Q1_test_words[idx] = text_to_word_list(test_Q1[idx])
    Q2_test_words[idx] = text_to_word_list(test_Q2[idx])

# %%
# make vocabulary 
vocab = {}
word_count = 0
for idx in range(len(train_Q1)):
    
    q = Q1_train_words[idx] + Q2_train_words[idx]
    for word in q:
        if word not in vocab:
            word_count += 1
            vocab[word] = word_count
print('The length of the vocabulary is: ', len(vocab))
# Out:
# The length of the vocabulary is:  62075

# %%
# import pre-trained word embeddings 
from gensim.models import KeyedVectors

embeddings = KeyedVectors.load_word2vec_format('/content/drive/My Drive/Embeddings/GoogleNews-vectors-negative300.bin.gz', binary = True)

# %%
# get pre-trained embeddings
def get_word_embeddings(vocab, embeddings):
    vocab_len = len(vocab)
    number_of_hits = 0;
    word_embeddings = np.zeros((vocab_len + 1, 300))
    for word, i in vocab.items():
        if word in embeddings.vocab:
            word_embeddings[i] = embeddings[word]
            number_of_hits += 1
    print(number_of_hits)
    return word_embeddings

# %%
word_embeddings = get_word_embeddings(vocab, embeddings)
# remove memory
del(embeddings)
# Out:
# 33507

# %%
# Converting questions to array of integers
for i in range(len(train_Q1)):
    Q1_train_tensor[i] = [vocab.get(word, 0) for word in Q1_train_words[i]]
    Q2_train_tensor[i] = [vocab.get(word, 0) for word in Q2_train_words[i]]

        
for i in range(len(test_Q1)):
    Q1_test_tensor[i] = [vocab.get(word, 0) for word in Q1_test_words[i]]
    Q2_test_tensor[i] = [vocab.get(word, 0) for word in Q2_test_words[i]]

# %%
class data_generator(tf.keras.utils.Sequence):
    def __init__(self, Q1, Q2, labels, batch_size, max_len, shuffle=True):
        self.Q1 = Q1
        self.Q2 = Q2
        self.labels = labels
        self.batch_size = batch_size
        self.max_len = max_len
        self.shuffle = shuffle
        
        self.indexes = np.arange(len(self.Q1))
        self.on_epoch_end()

    def __len__(self):
        # Denotes the number of batches per epoch.
        return len(self.Q1) // self.batch_size

    def __getitem__(self, idx):
        # Retrieves the batch of index.
        indexes = self.indexes[idx * self.batch_size : (idx + 1) * self.batch_size]
        input1 = self.Q1[indexes]
        input2 = self.Q2[indexes]
        targets = self.labels[indexes]
        
        pad_input1 = pad_sequences(input1, maxlen=self.max_len, padding='post')
        pad_input2 = pad_sequences(input2, maxlen=self.max_len, padding='post')

        return [pad_input1, pad_input2], targets


    def on_epoch_end(self):
        # Shuffle indexes after each epoch if shuffle is set to True.
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %%
# define model
def create_model(max_len, lstm_units, lr_rate, loss_fn):

    def exponent_neg_manhattan_distance(left, right):
        return K.exp(-K.sum(K.abs(left-right), axis=1, keepdims=True))


    # Input tensor placeholders
    left_input = tf.keras.Input(shape=(max_len,), dtype='int32')
    right_input = tf.keras.Input(shape=(max_len,), dtype='int32')

    # Embedding layer
    embedding_dim = 300
    embedding_layer = Embedding(len(vocab)+1, embedding_dim, weights=[word_embeddings], trainable=False)

    # Add the embedding dimension to input placeholders
    encoded_left = embedding_layer(left_input)
    encoded_right = embedding_layer(right_input)  

    # Initialise the LSTM
    shared_lstm = tf.keras.layers.LSTM(lstm_units)
    encoded_l = shared_lstm(encoded_left)
    encoded_r = shared_lstm(encoded_right)     

    # Calculates the manhattan distance
    # Add a customized layer to compute the absolute difference between the encodings
    L1_layer = tf.keras.layers.Lambda(lambda tensors: exponent_neg_manhattan_distance(tensors[0], tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])

    # Add a dense layer with a sigmoid unit to generate the similarity score
    prediction = tf.keras.layers.Dense(1, activation='sigmoid')(L1_distance)

    # Build the model
    model = tf.keras.Model(inputs=[left_input, right_input], outputs=[L1_distance])

    # compile model
    model.compile(
        optimizer = tf.keras.optimizers.Adam(learning_rate=lr_rate),
        loss = loss_fn,
        metrics = ['accuracy'],
    )

    return model

# %%
# Create the model under a distribution strategy scope.
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    loss_fn = tf.keras.losses.MeanSquaredError()
    model = create_model(max_len = 64,
                        lstm_units = 64,
                        lr_rate = 0.001,
                        loss_fn = loss_fn
                    )

# print(f"Strategy: {strategy}")
model.summary()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 64)]         0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 64)]         0
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 64, 300)      18622800    input_13[0][0]
#                                                                  input_14[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 64)           93440       embedding_6[0][0]
#                                                                  embedding_6[1][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 1)            0           lstm_6[0][0]
#                                                                  lstm_6[1][0]
# ==================================================================================================
# Total params: 18,716,240
# Trainable params: 93,440
# Non-trainable params: 18,622,800
# __________________________________________________________________________________________________

# %%
batch_size = 256
train_data = data_generator(
    Q1_train_tensor, 
    Q2_train_tensor, 
    t_labels, 
    batch_size, 
    64,
    )
valid_data = data_generator(
    Q1_test_tensor, 
    Q2_test_tensor, 
    te_labels, 
    batch_size, 
    64,
    shuffle=False,
    )

# %%
# # change learning rate

# tf.keras.backend.set_value(model.optimizer.lr, 0.001)
# print(tf.keras.backend.get_value(model.optimizer.lr))

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    min_delta=0,
    patience=3,
    verbose=0,
    mode="max",
    baseline=None,
    restore_best_weights=True,
)

# %%
epochs = 100
history = model.fit(
    train_data,
    validation_data=valid_data,
    epochs=epochs,
    callbacks = [callback],
    use_multiprocessing=True,
    workers=-1,
)
# Out:
# Epoch 1/100
# 480/480 [==============================] - 16s 24ms/step - loss: 0.2887 - accuracy: 0.5956 - val_loss: 0.2040 - val_accuracy: 0.6939
# Epoch 2/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1997 - accuracy: 0.7027 - val_loss: 0.1954 - val_accuracy: 0.7117
# Epoch 3/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1886 - accuracy: 0.7233 - val_loss: 0.1892 - val_accuracy: 0.7233
# Epoch 4/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1828 - accuracy: 0.7338 - val_loss: 0.1857 - val_accuracy: 0.7282
# Epoch 5/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1772 - accuracy: 0.7417 - val_loss: 0.1795 - val_accuracy: 0.7373
# Epoch 6/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1675 - accuracy: 0.7581 - val_loss: 0.1778 - val_accuracy: 0.7397
# Epoch 7/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1623 - accuracy: 0.7679 - val_loss: 0.1784 - val_accuracy: 0.7401
# Epoch 8/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1578 - accuracy: 0.7753 - val_loss: 0.1716 - val_accuracy: 0.7513
# Epoch 9/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1518 - accuracy: 0.7851 - val_loss: 0.1687 - val_accuracy: 0.7569
# Epoch 10/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1477 - accuracy: 0.7944 - val_loss: 0.1663 - val_accuracy: 0.7619
# Epoch 11/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1438 - accuracy: 0.8007 - val_loss: 0.1623 - val_accuracy: 0.7684
# Epoch 12/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1408 - accuracy: 0.8068 - val_loss: 0.1610 - val_accuracy: 0.7693
# Epoch 13/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1362 - accuracy: 0.8153 - val_loss: 0.1609 - val_accuracy: 0.7702
# Epoch 14/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1327 - accuracy: 0.8198 - val_loss: 0.1591 - val_accuracy: 0.7734
# Epoch 15/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1284 - accuracy: 0.8288 - val_loss: 0.1597 - val_accuracy: 0.7720
# Epoch 16/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1280 - accuracy: 0.8300 - val_loss: 0.1587 - val_accuracy: 0.7757
# Epoch 17/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1235 - accuracy: 0.8376 - val_loss: 0.1580 - val_accuracy: 0.7770
# Epoch 18/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1213 - accuracy: 0.8399 - val_loss: 0.1579 - val_accuracy: 0.7757
# Epoch 19/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1188 - accuracy: 0.8455 - val_loss: 0.1570 - val_accuracy: 0.7792
# Epoch 20/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1162 - accuracy: 0.8514 - val_loss: 0.1565 - val_accuracy: 0.7777
# Epoch 21/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1132 - accuracy: 0.8565 - val_loss: 0.1567 - val_accuracy: 0.7791
# Epoch 22/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1111 - accuracy: 0.8601 - val_loss: 0.1548 - val_accuracy: 0.7820
# Epoch 23/100
# 480/480 [==============================] - 10s 21ms/step - loss: 0.1083 - accuracy: 0.8648 - val_loss: 0.1569 - val_accuracy: 0.7799
# Epoch 24/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1077 - accuracy: 0.8658 - val_loss: 0.1544 - val_accuracy: 0.7820
# Epoch 25/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1050 - accuracy: 0.8707 - val_loss: 0.1542 - val_accuracy: 0.7824
# Epoch 26/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1046 - accuracy: 0.8725 - val_loss: 0.1545 - val_accuracy: 0.7833
# Epoch 27/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.1015 - accuracy: 0.8775 - val_loss: 0.1560 - val_accuracy: 0.7813
# Epoch 28/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.0993 - accuracy: 0.8806 - val_loss: 0.1546 - val_accuracy: 0.7813
# Epoch 29/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.0981 - accuracy: 0.8822 - val_loss: 0.1541 - val_accuracy: 0.7846
# Epoch 30/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.0955 - accuracy: 0.8877 - val_loss: 0.1559 - val_accuracy: 0.7836
# Epoch 31/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.0946 - accuracy: 0.8886 - val_loss: 0.1554 - val_accuracy: 0.7834
# Epoch 32/100
# 480/480 [==============================] - 10s 20ms/step - loss: 0.0930 - accuracy: 0.8904 - val_loss: 0.1541 - val_accuracy: 0.7830

# %%
preds = model.predict(
    valid_data,
    batch_size=batch_size,
    use_multiprocessing=True
)
# Out:
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, auc, roc_curve, confusion_matrix
y_pred = np.where(preds > 0.5, 1, 0)
n = y_pred.shape[0]
y_true = te_labels[:n]
print('accuracy: ', accuracy_score(y_true, y_pred))
print('F1 score: ', f1_score(y_true, y_pred))
print('Recall score: ', recall_score(y_true, y_pred))
print('Precision score: ', precision_score(y_true, y_pred))
fpr, tpr, thresholds = roc_curve(y_true, y_pred, pos_label=2)
print('AUC score: ', auc(fpr, tpr))
print('confusion matrix: \n', confusion_matrix(y_true, y_pred))
# Out:
# accuracy:  0.6987475198412698
# F1 score:  0.5134490977187607
# Recall score:  0.4302208498355374
# Precision score:  0.6366029302210082
# AUC score:  nan
# confusion matrix:
#  [[43529  7317]
#  [16976 12818]]

# %%
# draw plots
fig, axs = plt.subplots(1, 2, figsize=(12,4))
fig.suptitle('\nSiamese MaLSTM with Google News Vector Embedding', x=0.5, y=1.15,fontsize=16)

axs[0].plot(history.history['loss'], label='train loss')
axs[0].plot(history.history['val_loss'], label='val loss')
axs[0].set_title('\nModel loss plot', fontsize=16)
axs[0].set_xlabel('epochs', fontsize=20)
axs[0].set_ylabel('loss', fontsize=20)
axs[0].legend()

axs[1].plot(history.history['accuracy'], label='train accuracy')
axs[1].plot(history.history['val_accuracy'], label='val accuracy')
axs[1].set_title('\nModel accuracy graph', fontsize=16)
axs[1].set_xlabel('epochs', fontsize=20)
axs[1].set_ylabel('accuracy', fontsize=20)
axs[1].legend()

plt.show()

# %%
plt.figure(figsize=(11,6))
test_samples = preds.shape[0]
x = np.arange(test_samples)
plt.bar(x, preds.flatten())
plt.title('Question pairs Manhattan distance', fontsize=20)
plt.xlabel('Question pairs', fontsize=20)
plt.ylabel('Manhattan Distance', fontsize=20)
plt.show()

# %%
def separate_duplicates(y_true, y_preds):
    duplicates = []
    non_duplicates = []
    for i, y in enumerate(y_true):
        if y==1:
            duplicates.append(y_preds[i])
        else:
            non_duplicates.append(y_preds[i])
    return np.array(duplicates), np.array(non_duplicates)

# %%
duplicates, non_duplicates = separate_duplicates(y_true, preds.flatten())

# %%
plt.figure(figsize=(11,6))
x = np.arange(len(duplicates))
plt.bar(x, duplicates)
plt.title('Actual Duplicate question pairs Manhattan distance', fontsize=20)
plt.xlabel('Question pairs', fontsize=20)
plt.ylabel('Manhattan Distance', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(11,6))
x = np.arange(len(non_duplicates))
plt.bar(x, non_duplicates)
plt.title('Actual Non Duplicate question pairs Manhattan distance', fontsize=20)
plt.xlabel('Question pairs', fontsize=20)
plt.ylabel('Manhattan Distance', fontsize=20)
plt.show()
