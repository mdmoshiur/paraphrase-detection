# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_excel('/content/book.xlsx')

# %%
df2 = pd.read_excel('/content/book.xlsx')

# %%
dp3 = pd.read_excel('/content/book.xlsx')

# %%
dp1 = pd.read_excel('/content/book.xlsx')

# %%
dp2 = pd.read_excel('/content/book.xlsx')

# %%
dp4 = pd.read_excel('/content/book.xlsx')

# %%
dp5 = pd.read_excel('/content/book.xlsx')

# %%
df.columns
# Out:
# Index(['epoch', 'train loss', 'train acc', 'test loss', 'test acc',
#        'learning rate', 'batch size'],
#       dtype='object')

# %%
plt.plot(df1['epoch'], df1['train acc'], label='train variable lr')
plt.plot(df1['epoch'], df1['test acc'], label='test variable lr')
plt.plot(df2['epoch'], df2['train acc'], label='train fixed lr')
plt.plot(df2['epoch'], df2['test acc'], label='test fixed lr')
plt.title('\nModel accuracy', fontsize=16)
plt.xlabel('epochs', fontsize=20)
plt.ylabel('accuracy', fontsize=20)
plt.legend()

plt.show()

# %%
# draw plots

plt.plot(dp1['epoch'], dp1['test acc'], label='dropout 0.1')
plt.plot(dp2['epoch'], dp2['test acc'], label='dropout 0.2')
plt.plot(dp3['epoch'], dp3['test acc'], label='dropout 0.3')
plt.plot(dp4['epoch'], dp4['test acc'], label='dropout 0.4')
plt.plot(dp5['epoch'], dp5['test acc'], label='dropout 0.5')
plt.title('\nModel accuracy', fontsize=16)
plt.xlabel('epochs', fontsize=20)
plt.ylabel('accuracy', fontsize=20)
plt.legend()

plt.show()

# %%
# draw plots
fig, axs = plt.subplots(1, 2, figsize=(12,4))
fig.suptitle('\nSiamese BERT model', x=0.5, y=1.15,fontsize=16)

axs[0].plot(df['epoch'], df['train loss'], label='train loss')
axs[0].plot(df['epoch'], df['test loss'], label='val loss')
axs[0].set_title('\nModel loss', fontsize=16)
axs[0].set_xlabel('epochs', fontsize=20)
axs[0].set_ylabel('loss', fontsize=20)
axs[0].legend()

axs[1].plot(df['epoch'], df['train acc'], label='train accuracy')
axs[1].plot(df['epoch'], df['test acc'], label='val accuracy')
axs[1].set_title('\nModel accuracy', fontsize=16)
axs[1].set_xlabel('epochs', fontsize=20)
axs[1].set_ylabel('accuracy', fontsize=20)
axs[1].legend()

plt.show()
